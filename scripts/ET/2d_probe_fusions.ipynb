# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
x = np.load('../data/MOGL_COL/200207_COL_MOGL.npy')
x.shape
# Out:
# (200, 600)

# %%
x1 = glob.glob('../data/MOGL_COL/*.npy')
x2 = np.load(x1[2])
x2.shape
plt.imshow(x2,cmap='cividis')
plt.gca().set_aspect('equal')
plt.colorbar(fraction=.02)

# %%
x1 = glob.glob('../data/MOGL_YUK/*.npy')
x2 = np.load(x1[1])
x2.shape
plt.imshow(x2,cmap='cividis')
plt.gca().set_aspect('equal')

plt.colorbar(fraction=.02)
