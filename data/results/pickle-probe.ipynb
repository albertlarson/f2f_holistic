# %%
import pandas as pd

# %%
df = pd.read_pickle('../results/pickles/fin-columbia.pkl')
df
# Out:
#      sst zscorex shuffled  tts lag     basin nn_hid_lay_size  \
# 0   True   False    False  0.7   0  Columbia               4
# 1   True   False    False  0.7   0  Columbia              30
# 2   True   False    False  0.7   0  Columbia             200
# 3   True   False    False  0.7   0  Columbia            1000
# 4   True   False    False  0.7   0  Columbia          dcrrnn
# ..   ...     ...      ...  ...  ..       ...             ...
# 58  True   False    False  0.8  24  Columbia            1000
# 59  True   False    False  0.8  24  Columbia          dcrrnn
# 60  True   False    False  0.9   0  Columbia               4
# 61  True   False    False  0.9   0  Columbia              30
# 62  True   False    False  0.9   0  Columbia             200
#
#            input_shape    output_shape  train_len  train_time_min  test_len  \
# 0   (210, 1, 200, 600)  (210, 1, 1, 7)        147           0.150        63
# 1   (210, 1, 200, 600)  (210, 1, 1, 7)        147           0.150        63
# ...

# %%
df = pd.read_pickle('../results/pickles/fin-yukon.pkl')
df
# Out:
#      sst zscorex shuffled  tts lag  basin nn_hid_lay_size         input_shape  \
# 0   True   False    False  0.7   0  Yukon               4  (210, 1, 200, 800)
# 1   True   False    False  0.7   0  Yukon              30  (210, 1, 200, 800)
# 2   True   False    False  0.7   0  Yukon             200  (210, 1, 200, 800)
# 3   True   False    False  0.7   0  Yukon            1000  (210, 1, 200, 800)
# 4   True   False    False  0.7   0  Yukon          dcrrnn  (210, 1, 200, 800)
# 5   True   False    False  0.7   1  Yukon               4  (210, 1, 200, 800)
# 6   True   False    False  0.7   1  Yukon              30  (210, 1, 200, 800)
# 7   True   False    False  0.7   1  Yukon             200  (210, 1, 200, 800)
# 8   True   False    False  0.7   1  Yukon            1000  (210, 1, 200, 800)
# 9   True   False    False  0.7   1  Yukon          dcrrnn  (210, 1, 200, 800)
# 10  True   False    False  0.7   3  Yukon               4  (210, 1, 200, 800)
# ...
